# %%
pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\bs-c\anaconda3\lib\site-packages (from mlxtend) (1.15.3)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\bs-c\anaconda3\lib\site-packages (from mlxtend) (2.1.3)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\bs-c\anaconda3\lib\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\bs-c\anaconda3\lib\site-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\bs-c\anaconda3\lib\site-packages (from mlxtend) (3.10.0)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\bs-c\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bs-c\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\bs-c\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bs-c\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\bs-c\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\bs-c\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\bs-c\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bs-c\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bs-c\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bs-c\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bs-c\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\bs-c\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\bs-c\anaconda3\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.5.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 411.7 kB/s eta 0:00:03
#    --------------- ------------------------ 0.5/1.4 MB 411.7 kB/s eta 0:00:03
#    --------------- ------------------------ 0.5/1.4 MB 411.7 kB/s eta 0:00:03
#    ----------------------- ---------------- 0.8/1.4 MB 377.7 kB/s eta 0:00:02
#    ----------------------- ---------------- 0.8/1.4 MB 377.7 kB/s eta 0:00:02
#    ----------------------- ---------------- 0.8/1.4 MB 377.7 kB/s eta 0:00:02
#    ------------------------------- -------- 1.0/1.4 MB 384.7 kB/s eta 0:00:01
#    ------------------------------- -------- 1.0/1.4 MB 384.7 kB/s eta 0:00:01
#    ------------------------------- -------- 1.0/1.4 MB 384.7 kB/s eta 0:00:01
#    ------------------------------- -------- 1.0/1.4 MB 384.7 kB/s eta 0:00:01
#    ------------------------------- -------- 1.0/1.4 MB 384.7 kB/s eta 0:00:01
#    -------------------------------------- - 1.3/1.4 MB 341.6 kB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 339.3 kB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4
# Note: you may need to restart the kernel to use updated packages.

# %%
transactions = [['Bread', 'Milk'],
                ['Bread', 'Cheese', 'Juice', 'Eggs'],
                ['Milk', 'Cheese', 'Juice', 'Coke' ],
                ['Bread', 'Milk', 'Cheese', 'Juice'],
                ['Bread', 'Milk', 'Cheese', 'Coke']]


from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()

te.fit(transactions)

rows = te.transform(transactions)
print(rows)
# Out:
# [[ True False False False False  True]
#  [ True  True False  True  True False]
#  [False  True  True False  True  True]
#  [ True  True False False  True  True]
#  [ True  True  True False False  True]]

# %%
import pandas as pd

df_transactions = pd.DataFrame(rows, columns=te.columns_)
df_transactions
# Out:
#    Bread  Cheese   Coke   Eggs  Juice   Milk
# 0   True   False  False  False  False   True
# 1   True    True  False   True   True  False
# 2  False    True   True  False   True   True
# 3   True    True  False  False   True   True
# 4   True    True   True  False  False   True

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets = apriori(df_transactions, min_support=0.4, use_colnames=True)

frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets
# Out:
#     support                itemsets  length
# 0       0.8                 (Bread)       1
# 1       0.8                (Cheese)       1
# 2       0.4                  (Coke)       1
# 3       0.6                 (Juice)       1
# 4       0.8                  (Milk)       1
# 5       0.6         (Cheese, Bread)       2
# 6       0.4          (Juice, Bread)       2
# 7       0.6           (Milk, Bread)       2
# 8       0.4          (Cheese, Coke)       2
# 9       0.6         (Cheese, Juice)       2
# 10      0.6          (Cheese, Milk)       2
# 11      0.4            (Coke, Milk)       2
# 12      0.4           (Juice, Milk)       2
# 13      0.4  (Cheese, Juice, Bread)       3
# 14      0.4   (Cheese, Milk, Bread)       3
# 15      0.4    (Cheese, Coke, Milk)       3
# 16      0.4   (Cheese, Juice, Milk)       3

# %%
from mlxtend.frequent_patterns import association_rules

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)

rules = rules.sort_values(['confidence'], ascending =[False])
rules
# Out:
#         antecedents      consequents  antecedent support  consequent support  \
# 10           (Coke)           (Milk)                 0.4                 0.8
# 7           (Juice)         (Cheese)                 0.6                 0.8
# 5            (Coke)         (Cheese)                 0.4                 0.8
# 19   (Cheese, Coke)           (Milk)                 0.4                 0.8
# 21     (Coke, Milk)         (Cheese)                 0.4                 0.8
# 22           (Coke)   (Cheese, Milk)                 0.4                 0.6
# 25    (Juice, Milk)         (Cheese)                 0.4                 0.8
# 14   (Juice, Bread)         (Cheese)                 0.4                 0.8
# 6          (Cheese)          (Juice)                 0.8                 0.6
# 0          (Cheese)          (Bread)                 0.8                 0.8
# 1           (Bread)         (Cheese)                 0.8                 0.8
# 3            (Milk)          (Bread)                 0.8                 0.8
# 9            (Milk)         (Cheese)                 0.8                 0.8
# 4           (Bread)           (Milk)                 0.8                 0.8
# 8          (Cheese)           (Milk)                 0.8                 0.8
# 2           (Juice)          (Bread)                 0.6                 0.8
# 11          (Juice)           (Milk)                 0.6                 0.8
# 12  (Cheese, Juice)          (Bread)                 0.6                 0.8
# 13  (Cheese, Bread)          (Juice)                 0.6                 0.6
# 18    (Milk, Bread)         (Cheese)                 0.6                 0.8
# 17  (Cheese, Bread)           (Milk)                 0.6                 0.8
# 16   (Cheese, Milk)          (Bread)                 0.6                 0.8
# 15          (Juice)  (Cheese, Bread)                 0.6                 0.6
# 20   (Cheese, Milk)           (Coke)                 0.6                 0.4
# 23  (Cheese, Juice)           (Milk)                 0.6                 0.8
# 24   (Cheese, Milk)          (Juice)                 0.6                 0.6
# 26          (Juice)   (Cheese, Milk)                 0.6                 0.6
#
#     support  confidence      lift  representativity  leverage  conviction  \
# 10      0.4    1.000000  1.250000               1.0      0.08         inf
# 7       0.6    1.000000  1.250000               1.0      0.12         inf
# 5       0.4    1.000000  1.250000               1.0      0.08         inf
# 19      0.4    1.000000  1.250000               1.0      0.08         inf
# 21      0.4    1.000000  1.250000               1.0      0.08         inf
# 22      0.4    1.000000  1.666667               1.0      0.16         inf
# 25      0.4    1.000000  1.250000               1.0      0.08         inf
# 14      0.4    1.000000  1.250000               1.0      0.08         inf
# 6       0.6    0.750000  1.250000               1.0      0.12         1.6
# 0       0.6    0.750000  0.937500               1.0     -0.04         0.8
# 1       0.6    0.750000  0.937500               1.0     -0.04         0.8
# 3       0.6    0.750000  0.937500               1.0     -0.04         0.8
# 9       0.6    0.750000  0.937500               1.0     -0.04         0.8
# 4       0.6    0.750000  0.937500               1.0     -0.04         0.8
# 8       0.6    0.750000  0.937500               1.0     -0.04         0.8
# 2       0.4    0.666667  0.833333               1.0     -0.08         0.6
# 11      0.4    0.666667  0.833333               1.0     -0.08         0.6
# 12      0.4    0.666667  0.833333               1.0     -0.08         0.6
# 13      0.4    0.666667  1.111111               1.0      0.04         1.2
# 18      0.4    0.666667  0.833333               1.0     -0.08         0.6
# 17      0.4    0.666667  0.833333               1.0     -0.08         0.6
# 16      0.4    0.666667  0.833333               1.0     -0.08         0.6
# 15      0.4    0.666667  1.111111               1.0      0.04         1.2
# 20      0.4    0.666667  1.666667               1.0      0.16         1.8
# 23      0.4    0.666667  0.833333               1.0     -0.08         0.6
# 24      0.4    0.666667  1.111111               1.0      0.04         1.2
# 26      0.4    0.666667  1.111111               1.0      0.04         1.2
#
#     zhangs_metric   jaccard  certainty  kulczynski
# 10       0.333333  0.500000   1.000000    0.750000
# 7        0.500000  0.750000   1.000000    0.875000
# 5        0.333333  0.500000   1.000000    0.750000
# 19       0.333333  0.500000   1.000000    0.750000
# 21       0.333333  0.500000   1.000000    0.750000
# 22       0.666667  0.666667   1.000000    0.833333
# 25       0.333333  0.500000   1.000000    0.750000
# 14       0.333333  0.500000   1.000000    0.750000
# 6        1.000000  0.750000   0.375000    0.875000
# 0       -0.250000  0.600000  -0.250000    0.750000
# 1       -0.250000  0.600000  -0.250000    0.750000
# 3       -0.250000  0.600000  -0.250000    0.750000
# 9       -0.250000  0.600000  -0.250000    0.750000
# 4       -0.250000  0.600000  -0.250000    0.750000
# 8       -0.250000  0.600000  -0.250000    0.750000
# 2       -0.333333  0.400000  -0.666667    0.583333
# 11      -0.333333  0.400000  -0.666667    0.583333
# 12      -0.333333  0.400000  -0.666667    0.583333
# 13       0.250000  0.500000   0.166667    0.666667
# 18      -0.333333  0.400000  -0.666667    0.583333
# 17      -0.333333  0.400000  -0.666667    0.583333
# 16      -0.333333  0.400000  -0.666667    0.583333
# 15       0.250000  0.500000   0.166667    0.666667
# 20       1.000000  0.666667   0.444444    0.833333
# 23      -0.333333  0.400000  -0.666667    0.583333
# 24       0.250000  0.500000   0.166667    0.666667
# 26       0.250000  0.500000   0.166667    0.666667

# %%
from matplotlib import pyplot as plt
from pandas.plotting import parallel_coordinates

rules['antecedent'] = rules['antecedents'].apply(lambda a: ','.join(list(a)))

rules['consequent'] = rules['consequents'].apply(lambda a: ','.join(list(a)))

rules['rule_n'] = rules.index

coords=rules[['antecedent','consequent','rule_n']]

plt.figure(figsize=(4,8))

parallel_coordinates(coords, 'rule_n')

plt.legend([])

plt.grid(True)
plt.show()

# %%
import seaborn as sns

matrix = rules.pivot(index = 'antecedent', columns = 'consequent', values= 'confidence')
matrix
# Out:
# consequent       Bread    Cheese  Cheese,Bread  Cheese,Milk      Coke  \
# antecedent
# Bread              NaN  0.750000           NaN          NaN       NaN
# Cheese        0.750000       NaN           NaN          NaN       NaN
# Cheese,Bread       NaN       NaN           NaN          NaN       NaN
# Cheese,Coke        NaN       NaN           NaN          NaN       NaN
# Cheese,Juice  0.666667       NaN           NaN          NaN       NaN
# Cheese,Milk   0.666667       NaN           NaN          NaN  0.666667
# Coke               NaN  1.000000           NaN     1.000000       NaN
# Coke,Milk          NaN  1.000000           NaN          NaN       NaN
# Juice         0.666667  1.000000      0.666667     0.666667       NaN
# Juice,Bread        NaN  1.000000           NaN          NaN       NaN
# Juice,Milk         NaN  1.000000           NaN          NaN       NaN
# Milk          0.750000  0.750000           NaN          NaN       NaN
# Milk,Bread         NaN  0.666667           NaN          NaN       NaN
#
# consequent       Juice      Milk
# antecedent
# Bread              NaN  0.750000
# Cheese        0.750000  0.750000
# Cheese,Bread  0.666667  0.666667
# Cheese,Coke        NaN  1.000000
# Cheese,Juice       NaN  0.666667
# Cheese,Milk   0.666667       NaN
# Coke               NaN  1.000000
# Coke,Milk          NaN       NaN
# Juice              NaN  0.666667
# Juice,Bread        NaN       NaN
# Juice,Milk         NaN       NaN
# Milk               NaN       NaN
# Milk,Bread         NaN       NaN

# %%
sns.heatmap(matrix, annot = True)

plt.yticks(rotation=0)

plt.xticks(rotation=90)
plt.show()

# %%
def predict(items, rules, max_results= 6):
    
    preds = rules[rules['antecedents'] == items]
    
    preds = preds[['consequent','confidence']]
    
    preds.sort_values('confidence', ascending=False)
    
    return preds[:max_results]

preds = predict({'Cheese','Milk'}, rules)
preds
# Out:
#    consequent  confidence
# 16      Bread    0.666667
# 20       Coke    0.666667
# 24      Juice    0.666667
